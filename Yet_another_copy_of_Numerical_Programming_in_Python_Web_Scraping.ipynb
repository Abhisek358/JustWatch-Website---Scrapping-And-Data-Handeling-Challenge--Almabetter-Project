# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhisek358/JustWatch-Website---Scrapping-And-Data-Handeling-Challenge--Almabetter-Project/blob/main/Yet_another_copy_of_Numerical_Programming_in_Python_Web_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Web Scraping & Data Handling Challenge**

# %% [markdown]
# ### **Website:**
# JustWatch -  https://www.justwatch.com/in/movies?release_year_from=2000
#
#
# ### **Description:**
#
# JustWatch is a popular platform that allows users to search for movies and TV shows across multiple streaming services like Netflix, Amazon Prime, Hulu, etc. For this assignment, you will be required to scrape movie and TV show data from JustWatch using Selenium, Python, and BeautifulSoup. Extract data from HTML, not by directly calling their APIs. Then, perform data filtering and analysis using Pandas, and finally, save the results to a CSV file.
#
# ### **Tasks:**
#
# **1. Web Scraping:**
#
# Use BeautifulSoup to scrape the following data from JustWatch:
#
#    **a. Movie Information:**
#
#       - Movie title
#       - Release year
#       - Genre
#       - IMDb rating
#       - Streaming services available (Netflix, Amazon Prime, Hulu, etc.)
#       - URL to the movie page on JustWatch
#
#    **b. TV Show Information:**
#
#       - TV show title
#       - Release year
#       - Genre
#       - IMDb rating
#       - Streaming services available (Netflix, Amazon Prime, Hulu, etc.)
#       - URL to the TV show page on JustWatch
#
#   **c. Scope:**
#
# ```
#  ` - Scrape data for at least 50 movies and 50 TV shows.
#    - You can choose the entry point (e.g., starting with popular movies,
#      or a specific genre, etc.) to ensure a diverse dataset.`
#
# ```
#
#
# **2. Data Filtering & Analysis:**
#
#    After scraping the data, use Pandas to perform the following tasks:
#
#    **a. Filter movies and TV shows based on specific criteria:**
#
#    ```
#       - Only include movies and TV shows released in the last 2 years (from the current date).
#       - Only include movies and TV shows with an IMDb rating of 7 or higher.
# ```
#
#    **b. Data Analysis:**
#
#    ```
#       - Calculate the average IMDb rating for the scraped movies and TV shows.
#       - Identify the top 5 genres that have the highest number of available movies and TV shows.
#       - Determine the streaming service with the most significant number of offerings.
#
#    ```
#
# **3. Data Export:**
#
# ```
#    - Dump the filtered and analysed data into a CSV file for further processing and reporting.
#
#    - Keep the CSV file in your Drive Folder and Share the Drive link on the colab while keeping view access with anyone.
# ```
#
# **Submission:**
# ```
# - Submit a link to your Colab made for the assignment.
#
# - The Colab should contain your Python script (.py format only) with clear
#   comments explaining the scraping, filtering, and analysis process.
#
# - Your Code shouldn't have any errors and should be executable at a one go.
#
# - Before Conclusion, Keep your Dataset Drive Link in the Notebook.
# ```
#
#
#
# **Note:**
#
# 1. Properly handle errors and exceptions during web scraping to ensure a robust script.
#
# 2. Make sure your code is well-structured, easy to understand, and follows Python best practices.
#
# 3. The assignment will be evaluated based on the correctness of the scraped data, accuracy of data filtering and analysis, and the overall quality of the Python code.

# %% [markdown]
# # **Start The Project**

# %% [markdown]
# ## **Task 1:- Web Scrapping**

# %%
#Installing all necessary labraries
# !pip install bs4
# !pip install requests

# %%
#import all necessary labraries
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np
import time

# %% [markdown]
# ## **Scrapping Movies Data**

# %%
# Specifying the URL from which movies related data will be fetched
url='https://www.justwatch.com/in/movies?release_year_from=2000'

# Sending an HTTP GET request to the URL
response=requests.get(url)
# Parsing the HTML content using BeautifulSoup with the 'html.parser'
soup=BeautifulSoup(response.text,'html.parser')
# Printing the prettified HTML content
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-vue-meta="%7B%22dir%22:%7B%22ssr%22:%22ltr%22%7D,%22lang%22:%7B%22ssr%22:%22en%22%7D%7D" data-vue-meta-server-rendered="" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8" data-vue-meta="ssr"/>
#   <meta content="IE=edge" data-vue-meta="ssr" httpequiv="X-UA-Compatible"/>
#   <meta content="viewport-fit=cover, width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" data-vue-meta="ssr" name="viewport"/>
#   <meta content="JustWatch" data-vue-meta="ssr" property="og:site_name"/>
#   <meta content="794243977319785" data-vue-meta="ssr" property="fb:app_id"/>
#   <meta content="/appassets/img/JustWatch_logo_with_claim.png" data-vmid="og:image" data-vue-meta="ssr" property="og:image"/>
#   <meta content="606" data-vmid="og:image:width" data-vue-meta="ssr" property="og:image:width"/>
# ...

# %% [markdown]
# ## **Fetching Movie URL's**

# %%
# Write Your Code here
list_of_links = []
main_web_url = r"https://www.justwatch.com"
ancher_tag = soup.find_all('a', class_ = "title-list-grid__item--link")

for tag in ancher_tag:
  href = tag.get("href")


# print(ancher_tag)
# href = ancher_tag.get("href")

  link = main_web_url+ href
  # print(link)
  list_of_links.append(link)
print(list_of_links)
# print(len(list_of_links))
# Out:
# ['https://www.justwatch.com/in/movie/laapataa-ladies', 'https://www.justwatch.com/in/movie/untitled-shahid-kapoor-kriti-sanon-film', 'https://www.justwatch.com/in/movie/premalu', 'https://www.justwatch.com/in/movie/article-370', 'https://www.justwatch.com/in/movie/dune-part-two', 'https://www.justwatch.com/in/movie/hanu-man', 'https://www.justwatch.com/in/movie/oppenheimer', 'https://www.justwatch.com/in/movie/the-crew-2024', 'https://www.justwatch.com/in/movie/manjummel-boys', 'https://www.justwatch.com/in/movie/amar-singh-chamkila', 'https://www.justwatch.com/in/movie/anyone-but-you', 'https://www.justwatch.com/in/movie/anatomie-dune-chute', 'https://www.justwatch.com/in/movie/black-magic-2024', 'https://www.justwatch.com/in/movie/kung-fu-panda-4', 'https://www.justwatch.com/in/movie/dune-2021', 'https://www.justwatch.com/in/movie/monkey-man', 'https://www.justwatch.com/in/movie/animal-2022', 'https://www.justwatch.com/in/movie/family-star', 'https://www.justwatch.com/in/movie/12th
# ...

# %% [markdown]
# ## **Scrapping Movie Title**

# %%
# Write Your Code here
list_of_movies_titles = []
for link in list_of_links:
  try:
    response = requests.get(link)
    soup = BeautifulSoup(response.text, "html.parser")

    title_tag = soup.find("h1")
    title = title_tag.text
    list_of_movies_titles.append(title)

  except Exception as e:
    print(e)
  time.sleep(3)

print(list_of_movies_titles)
print(len(list_of_movies_titles))
# Out:
# [' Laapataa Ladies ', ' Teri Baaton Mein Aisa Uljha Jiya ', ' Premalu ', ' Article 370 ', ' Dune: Part Two ', ' Hanu-Man ', ' Oppenheimer ', ' Crew ', ' Manjummel Boys ', ' Amar Singh Chamkila ', ' Anyone But You ', ' Anatomy of a Fall ', ' Shaitaan ', ' Kung Fu Panda 4 ', ' Dune ', ' Monkey Man ', ' Animal ', ' Family Star ', ' 12th Fail ', ' Fighter ', ' Tillu Square ', ' Gaami ', ' The Beekeeper ', ' Godzilla x Kong: The New Empire ', ' Yodha ', ' Bramayugam ', ' Madgaon Express ', ' Poor Things ', ' 777 Charlie ', ' DJ Tillu ', ' Sam Bahadur ', ' 365 Days ', ' Kung Fu Panda ', ' Salaar ', ' Om Bheem Bush ', ' Madame Web ', ' Road House ', ' Bade Miyan Chote Miyan ', ' Godzilla Minus One ', ' Kampon ', ' Crakk: Jeetega... Toh Jiyegaa ', " Harry Potter and the Philosopher's Stone ", ' Chaari 111 ', ' The Goat Life ', ' Maidaan ', ' Aquaman and the Lost Kingdom ', ' Speak No Evil ', ' Argylle ', ' Aavesham ', ' The Kerala Story ', ' Rebel Moon - Part Two: The Scargiver ', ' Godzilla
# ...

# %% [markdown]
# ## **Scrapping release Year**

# %%
# Write Your Code here
list_of_movies_release_year = []
for link in list_of_links:
  try:
    response = requests.get(link)
    soup = BeautifulSoup(response.text, "html.parser")

    release_tag = soup.find("span", class_ = "text-muted")
    release_year = release_tag.text
    list_of_movies_release_year.append(release_year)

  except Exception as e:
    print(e)
  time.sleep(3)

print(list_of_movies_release_year)
print(len(list_of_movies_release_year))
# Out:
# [' (2024) ', ' (2024) ', ' (2024) ', ' (2024) ', ' (2024) ', ' (2024) ', ' (2023) ', ' (2024) ', ' (2024) ', ' (2024) ', ' (2024) ', ' (2023) ', ' (2024) ', ' (2024) ', ' (2021) ', ' (2024) ', ' (2023) ', ' (2024) ', ' (2023) ', ' (2024) ', ' (2024) ', ' (2024) ', ' (2024) ', ' (2024) ', ' (2024) ', ' (2024) ', ' (2024) ', ' (2023) ', ' (2022) ', ' (2022) ', ' (2023) ', ' (2020) ', ' (2008) ', ' (2023) ', ' (2024) ', ' (2024) ', ' (2024) ', ' (2024) ', ' (2023) ', ' (2023) ', ' (2024) ', ' (2001) ', ' (2024) ', ' (2024) ', ' (2022) ', ' (2023) ', ' (2022) ', ' (2024) ', ' (2024) ', ' (2023) ', ' (2024) ', ' (2021) ', ' (2019) ', ' (2023) ', ' (2024) ', ' (2024) ', ' (2023) ', ' (2024) ', ' (2014) ', ' (2024) ', ' (2021) ', ' (2012) ', ' (2024) ', ' (2013) ', ' (2024) ', ' (2022) ', ' (2019) ', ' (2024) ', ' (2018) ', ' (2014) ', ' (2024) ', ' (2023) ', ' (2024) ', ' (2024) ', ' (2024) ', ' (2024) ', ' (2023) ', ' (2024) ', ' (2022) ', ' (2023) ', ' (2024) ', ' (2024) ', ' (2024) ', '
# ...

# %% [markdown]
# ## **Scrapping Genres**

# %%
# Write Your Code here
list_of_movies_genres = []
for link in list_of_links:
  try:
    response = requests.get(link)
    soup = BeautifulSoup(response.text, "html.parser")

    genre_heading= soup.find("h3", class_ = "detail-infos__subheading", string= "Genres")

    if genre_heading:
      genre = genre_heading.find_next("div", class_ = "detail-infos__value")
      list_of_movies_genres.append(genre.text)
    else:
      list_of_movies_genres.append("genre Not Found")

  except Exception as e:
    print(e)
  time.sleep(3)

print(list_of_movies_genres)
print(len(list_of_movies_genres))
# Out:
# ['Comedy, Drama', 'Comedy, Drama, Romance, Science-Fiction', 'Romance, Comedy', 'Drama, Mystery & Thriller, Action & Adventure', 'Action & Adventure, Science-Fiction, Drama', 'Science-Fiction, Fantasy, Action & Adventure, Comedy', 'Drama, History', 'Drama, Comedy', 'Mystery & Thriller, Action & Adventure, Drama', 'Drama, Music & Musical, Romance', 'Romance, Comedy', 'Mystery & Thriller, Drama, Crime', 'Mystery & Thriller, Drama, Horror', 'Animation, Action & Adventure, Comedy, Kids & Family, Fantasy', 'Science-Fiction, Action & Adventure, Drama', 'Action & Adventure, Mystery & Thriller', 'Action & Adventure, Crime, Drama, Mystery & Thriller', 'Drama, Kids & Family, Romance, Action & Adventure, Comedy', 'Drama', 'Mystery & Thriller, War & Military, Action & Adventure', 'Drama, Comedy, Crime, Mystery & Thriller', 'Fantasy, Mystery & Thriller, Science-Fiction, Drama', 'Mystery & Thriller, Drama, Action & Adventure', 'Science-Fiction, Mystery & Thriller, Action & Adventure', 'Action & Ad
# ...

# %% [markdown]
# ## **Scrapping IMBD Rating**

# %%
# Write Your Code here
list_of_movies_rating = []
for link in list_of_links:
  try:
    response = requests.get(link)
    soup = BeautifulSoup(response.text, "html.parser")
    rating_tag = soup.find_all("div", class_ = "jw-scoring-listing__rating")
    if rating_tag:
      rating = rating_tag[1].text.split("(")[0]
      list_of_movies_rating.append(rating)

    else:
      list_of_movies_rating.append("rating not found")

  except Exception as e:
    print(e)
  time.sleep(2)

print(list_of_movies_rating)
print(len(list_of_movies_rating))
# Out:
# [' 8.5  ', ' 6.4  ', ' 7.9  ', ' 8.1  ', ' 8.7  ', ' 7.9  ', ' 8.3  ', ' 6.5  ', ' 8.6  ', 'rating not found', ' 6.2  ', 'rating not found', ' 7.2  ', ' 6.3  ', 'rating not found', 'rating not found', 'rating not found', ' 5.1  ', ' 9.0  ', 'rating not found', ' 6.9  ', 'rating not found', ' 6.4  ', ' 6.5  ', 'rating not found', ' 7.9  ', 'rating not found', ' 7.9  ', 'rating not found', ' 7.2  ', ' 7.8  ', 'rating not found', ' 7.6  ', 'rating not found', ' 5.8  ', ' 3.8  ', 'rating not found', ' 4.8  ', 'rating not found', ' 4.8  ', 'rating not found', ' 7.6  ', ' 5.2  ', 'rating not found', ' 8.5  ', 'rating not found', ' 6.6  ', ' 5.7  ', 'rating not found', ' 7.0  ', 'rating not found', ' 6.3  ', ' 8.4  ', 'rating not found', ' 7.0  ', 'rating not found', ' 6.7  ', ' 6.8  ', 'rating not found', ' 7.0  ', 'rating not found', ' 7.6  ', 'rating not found', ' 8.1  ', ' 6.3  ', 'rating not found', ' 7.8  ', 'rating not found', ' 6.3  ', ' 8.7  ', 'rating not found', ' 6.8  ', 'rating
# ...

# %% [markdown]
# ## **Scrapping Runtime/Duration**

# %%
# Write Your Code here
list_of_movies_runtime = []
for link in list_of_links:
  try:
    response = requests.get(link)
    soup = BeautifulSoup(response.text, "html.parser")

    runtime_heading= soup.find("h3", class_ = "detail-infos__subheading", string= "Runtime")

    if runtime_heading:
      runtime = runtime_heading.find_next("div", class_ = "detail-infos__value")
      list_of_movies_runtime.append(runtime.text)
    else:
      list_of_movies_runtime.append("runtime Not Found")

  except Exception as e:
    print(e)
  time.sleep(3)

print(list_of_movies_runtime)
print(len(list_of_movies_runtime))
# Out:
# ['2h 2min', '2h 21min', '2h 36min', '2h 38min', '2h 47min', '2h 39min', '3h 0min', '1h 58min', '2h 15min', '2h 25min', '1h 43min', '2h 32min', '2h 8min', '1h 34min', '2h 36min', '2h 1min', '3h 21min', '2h 39min', '2h 27min', '2h 47min', '2h 27min', '2h 27min', '1h 45min', '1h 55min', '2h 10min', '2h 19min', '2h 23min', '2h 22min', '2h 46min', '2h 1min', '2h 30min', '1h 54min', '1h 30min', '2h 55min', '2h 30min', '1h 56min', '2h 1min', '2h 44min', '2h 5min', '1h 31min', '2h 34min', '2h 32min', '2h 7min', '2h 52min', '3h 1min', '2h 4min', '1h 37min', '2h 19min', '2h 38min', '2h 18min', '2h 3min', '1h 53min', '2h 2min', '1h 57min', '2h 25min', '2h 19min', '1h 23min', '2h 6min', '2h 2min', '2h 23min', '2h 59min', '1h 41min', '2h 22min', '2h 3min', '2h 22min', '1h 31min', '1h 47min', '2h 30min', '2h 2min', '2h 49min', '1h 56min', '2h 20min', '2h 12min', '2h 12min', '1h 43min', '1h 41min', '2h 15min', '2h 39min', '2h 46min', '2h 40min', '1h 49min', '2h 56min', '2h 21min', '2h 0min', '2h 39
# ...

# %% [markdown]
# ## **Scrapping Age Rating**

# %%
# Write Your Code here
list_of_movies_age_rating = []
for link in list_of_links:
  try:
    response = requests.get(link)
    soup = BeautifulSoup(response.text, "html.parser")

    age_rating_heading= soup.find("h3", class_ = "detail-infos__subheading", string= "Age rating")

    if age_rating_heading:
      age_rating = age_rating_heading.find_next("div", class_ = "detail-infos__value")
      list_of_movies_age_rating.append(age_rating.text)
    else:
      list_of_movies_age_rating.append("age_rating Not Found")
  except Exception as e:
    print(e)
  time.sleep(2)

print(list_of_movies_age_rating)
print(len(list_of_movies_age_rating))
# Out:
# ['UA', 'age_rating Not Found', 'U', 'age_rating Not Found', 'age_rating Not Found', 'UA', 'UA', 'UA', 'UA', 'age_rating Not Found', 'A', 'age_rating Not Found', 'UA', 'age_rating Not Found', 'UA', 'age_rating Not Found', 'A', 'age_rating Not Found', 'age_rating Not Found', 'UA', 'age_rating Not Found', 'A', 'age_rating Not Found', 'UA', 'UA', 'UA', 'UA', 'A', 'UA', 'UA', 'UA', 'age_rating Not Found', 'U', 'A', 'age_rating Not Found', 'age_rating Not Found', 'age_rating Not Found', 'UA', 'age_rating Not Found', 'A', 'UA', 'U', 'age_rating Not Found', 'UA', 'age_rating Not Found', 'age_rating Not Found', 'age_rating Not Found', 'age_rating Not Found', 'age_rating Not Found', 'A', 'age_rating Not Found', 'UA', 'A', 'UA', 'age_rating Not Found', 'UA', 'U', 'UA', 'A', 'age_rating Not Found', 'UA', 'A', 'age_rating Not Found', 'UA', 'A', 'age_rating Not Found', 'UA', 'age_rating Not Found', 'age_rating Not Found', 'age_rating Not Found', 'age_rating Not Found', 'UA', 'A', 'age_rating Not F
# ...

# %% [markdown]
# ## **Fetching Streaming Service Details**

# %%
# Write Your Code here
list_of_movies_streaming_services = []
for link in list_of_links:
  try:
    response = requests.get(link)
    soup = BeautifulSoup(response.text, "html.parser")

    streaming_tag = soup.find("img", class_ = "offer__icon")

    if streaming_tag:
      streaming_services = streaming_tag.get("alt")
      list_of_movies_streaming_services.append(streaming_services)
    else:
      list_of_movies_streaming_services.append("streaming services not found")

  except Exception as e:
    print(e)
  time.sleep(3)
print(list_of_movies_streaming_services)
# Out:
# ['Netflix', 'Amazon Prime Video', 'aha', 'Netflix', 'Apple TV', 'Jio Cinema', 'Apple TV', 'Bookmyshow', 'Bookmyshow', 'Netflix', 'Apple TV', 'Amazon Prime Video', 'Netflix', 'Apple TV', 'Apple TV', 'streaming services not found', 'Netflix', 'Amazon Prime Video', 'Hotstar', 'Netflix', 'Netflix', 'Zee5', 'Lionsgate Play', 'Bookmyshow', 'Amazon Video', 'Sony Liv', 'Amazon Video', 'Apple TV', 'Amazon Prime Video', 'Sony Liv', 'Zee5', 'Netflix', 'Apple TV', 'Netflix', 'Amazon Prime Video', 'Apple TV', 'Amazon Prime Video', 'Bookmyshow', 'streaming services not found', 'Netflix', 'streaming services not found', 'Apple TV', 'Amazon Prime Video', 'streaming services not found', 'Bookmyshow', 'Apple TV', 'Amazon Prime Video', 'Apple TV Plus', 'Bookmyshow', 'Zee5', 'Netflix', 'Amazon Prime Video', 'Amazon Prime Video', 'Amazon Prime Video', 'streaming services not found', 'Amazon Prime Video', 'Apple TV', 'Amazon Prime Video', 'Amazon Prime Video', 'Netflix', 'Amazon Prime Video', 'Apple TV', 
# ...

# %% [markdown]
# ## **Now Creating Movies DataFrame**

# %%
# Write Your Code here
movie_dic_df = {
    "Movie-Title" : list_of_movies_titles,
    "Release-Year" : list_of_movies_release_year,
    "Genre": list_of_movies_genres,
    "IMDB-Rating" : list_of_movies_rating,
    "Runtime": list_of_movies_runtime,
    "Age-Rating": list_of_movies_age_rating,
    "Streaming-Services": list_of_movies_streaming_services,
    "Links": list_of_links,

}

movie_df = pd.DataFrame(movie_dic_df)
movie_df
# Out:
#                            Movie-Title Release-Year  \
# 0                     Laapataa Ladies       (2024)
# 1    Teri Baaton Mein Aisa Uljha Jiya       (2024)
# 2                             Premalu       (2024)
# 3                         Article 370       (2024)
# 4                      Dune: Part Two       (2024)
# ..                                 ...          ...
# 95                               DeAr       (2024)
# 96               New York, I Love You       (2008)
# 97                         The Intern       (2015)
# 98    Rocky Aur Rani Kii Prem Kahaani       (2023)
# 99                Operation Valentine       (2024)
#
#                                                 Genre       IMDB-Rating  \
# 0                                       Comedy, Drama             8.5
# 1             Comedy, Drama, Romance, Science-Fiction             6.4
# 2                                     Romance, Comedy             7.9
# ...

# %% [markdown]
# ## **Scraping TV  Show Data**

# %%
# Specifying the URL from which tv show related data will be fetched
tv_url='https://www.justwatch.com/in/tv-shows?release_year_from=2000'
# Sending an HTTP GET request to the URL
response=requests.get(tv_url)
# Parsing the HTML content using BeautifulSoup with the 'html.parser'
soup=BeautifulSoup(response.text,'html.parser')
# Printing the prettified HTML content
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-vue-meta="%7B%22dir%22:%7B%22ssr%22:%22ltr%22%7D,%22lang%22:%7B%22ssr%22:%22en%22%7D%7D" data-vue-meta-server-rendered="" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8" data-vue-meta="ssr"/>
#   <meta content="IE=edge" data-vue-meta="ssr" httpequiv="X-UA-Compatible"/>
#   <meta content="viewport-fit=cover, width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" data-vue-meta="ssr" name="viewport"/>
#   <meta content="JustWatch" data-vue-meta="ssr" property="og:site_name"/>
#   <meta content="794243977319785" data-vue-meta="ssr" property="fb:app_id"/>
#   <meta content="/appassets/img/JustWatch_logo_with_claim.png" data-vmid="og:image" data-vue-meta="ssr" property="og:image"/>
#   <meta content="606" data-vmid="og:image:width" data-vue-meta="ssr" property="og:image:width"/>
# ...

# %% [markdown]
# ## **Fetching Tv shows Url details**

# %%
# Write Your Code here
list_of_link_for_tv_show = []
main_web_url_for_tv_show = r"https://www.justwatch.com"

ancher_tag = soup.find_all("a",class_ = "title-list-grid__item--link")
for tag in ancher_tag:
  href = tag.get("href")
  link = main_web_url_for_tv_show + href
  list_of_link_for_tv_show.append(link)
  print(list_of_link_for_tv_show)

# %% [markdown]
# ## **Fetching Tv Show Title details**

# %%
# Write Your Code here
list_of_tv_show_title = []
for link in list_of_link_for_tv_show:
  try:
    response = requests.get(link)
    soup = BeautifulSoup(response.text, "html.parser")

    title_heading = soup.find("h1")
    if title_heading:

      title = title_heading.text
      list_of_tv_show_title.append(title)

    else:
     title = "title not found"
  except Exception as e:
    print(e)

  time.sleep(3)

print(list_of_tv_show_title)
# Out:
# [' Shōgun ', ' Fallout ', ' Panchayat ', ' Mirzapur ', ' 3 Body Problem ', ' Game of Thrones ', ' Heeramandi: The Diamond Bazaar ', ' Apharan ', ' Attack on Titan ', ' Ripley ', ' Baby Reindeer ', ' Young Sheldon ', ' Inspector Rishi ', ' Dead Boy Detectives ', ' A Gentleman in Moscow ', ' The Great Indian Kapil Show ', ' Sunflower ', ' The Gentlemen ', ' Solo Leveling ', ' The Walking Dead ', ' Parasyte: The Grey ', ' Farzi ', ' Queen of Tears ', ' Mastram ', ' Lucifer ', ' Maharani ', ' Jujutsu Kaisen ', ' Anthracite ', ' Maamla Legal Hai ', ' Invincible ', ' Aashram ', ' Gandii Baat ', ' The Family Man ', ' True Detective ', ' The Rookie ', ' Sugar ', ' Euphoria ', ' Broken But Beautiful ', ' Reacher ', ' We Were the Lucky Ones ', ' Asur: Welcome to Your Dark Side ', ' The Last of Us ', ' Damaged ', ' The Flash ', ' Modern Family ', ' Money Heist ', ' Naruto Shippūden ', ' Breaking Bad ', ' Goodbye Earth ', ' Dehati Ladke ', ' House of the Dragon ', ' Stranger Things ', ' Peaky Bl
# ...

# %% [markdown]
# ## **Fetching Release Year**

# %%
# Write Your Code here
list_of_tv_show_release_year = []
for link in list_of_link_for_tv_show:
  try:
    response = requests.get(link)
    soup = BeautifulSoup(response.text, "html.parser")

    relase_year_heading = soup.find("span", class_ = "text-muted")
    release_year = relase_year_heading.text
    list_of_tv_show_release_year.append(release_year)

  except Exception as e:
    print(e)
  time.sleep(3)

print(list_of_tv_show_release_year)
print(len(list_of_tv_show_release_year))
# Out:
# [' (2024) ', ' (2024) ', ' (2020) ', ' (2018) ', ' (2024) ', ' (2011) ', ' (2024) ', ' (2018) ', ' (2013) ', ' (2024) ', ' (2024) ', ' (2017) ', ' (2024) ', ' (2024) ', ' (2024) ', ' (2024) ', ' (2021) ', ' (2024) ', ' (2024) ', ' (2010) ', ' (2024) ', ' (2023) ', ' (2024) ', ' (2020) ', ' (2016) ', ' (2021) ', ' (2020) ', ' (2024) ', ' (2024) ', ' (2021) ', ' (2020) ', ' (2018) ', ' (2019) ', ' (2014) ', ' (2018) ', ' (2024) ', ' (2019) ', ' (2018) ', ' (2022) ', ' (2024) ', ' (2020) ', ' (2023) ', ' (2018) ', ' (2014) ', ' (2009) ', ' (2017) ', ' (2007) ', ' (2008) ', ' (2024) ', ' (2023) ', ' (2022) ', ' (2016) ', ' (2013) ', ' (2024) ', ' (2002) ', ' (2020) ', ' (2002) ', ' (2017) ', ' (2024) ', ' (2020) ', ' (2024) ', ' (2018) ', ' (2024) ', ' (2008) ', ' (2019) ', ' (2011) ', ' (2021) ', ' (2015) ', ' (2021) ', ' (2023) ', ' (2004) ', ' (2019) ', ' (2005) ', ' (2022) ', ' (2022) ', ' (2013) ', ' (2006) ', ' (2023) ', ' (2023) ', ' (2018) ', ' (2024) ', ' (2009) ', ' (2021) ', '
# ...

# %% [markdown]
# ## **Fetching TV Show Genre Details**

# %%
# Write Your Code here
list_of_tv_show_genre = []
for link in list_of_link_for_tv_show:
  try:
    response = requests.get(link)
    soup = BeautifulSoup(response.text, "html.parser")

    genre_heading = soup.find("h3", class_ = "detail-infos__subheading", string = "Genres" )

    if genre_heading:
      genre = genre_heading.find_next("div", class_ = "detail-infos__value")
      list_of_tv_show_genre.append(genre.text)

    else:
      list_of_tv_show_genre.append("Genre not found")
  except Exception as e:
    print(e)
  time.sleep(3)

print(list_of_tv_show_genre)
print(len(list_of_tv_show_genre))
# Out:
# ['Drama, War & Military, History', 'Action & Adventure, Drama, Science-Fiction, War & Military, Comedy', 'Drama, Comedy', 'Crime, Action & Adventure, Drama, Mystery & Thriller', 'Mystery & Thriller, Drama, Science-Fiction, Fantasy', 'Action & Adventure, Drama, Fantasy, Science-Fiction', 'Romance, Drama, History', 'Drama, Crime, Mystery & Thriller, Action & Adventure', 'Action & Adventure, Drama, Fantasy, Horror, Animation, Science-Fiction', 'Drama, Mystery & Thriller, Crime', 'Drama, Comedy', 'Comedy, Kids & Family', 'Horror, Mystery & Thriller, Action & Adventure, Drama', 'Comedy, Crime, Drama, Fantasy, Horror, Action & Adventure, Science-Fiction', 'Drama, History, Mystery & Thriller', 'Comedy', 'Comedy, Crime', '', 'Action & Adventure, Fantasy, Animation, Science-Fiction', 'Action & Adventure, Drama, Science-Fiction, Horror, Mystery & Thriller', 'Drama, Action & Adventure, Horror, Science-Fiction, Mystery & Thriller', 'Crime, Drama, Mystery & Thriller', 'Comedy, Drama, Kids & Famil
# ...

# %% [markdown]
# ## **Fetching IMDB Rating Details**

# %%
# Write Your Code here
list_of_tv_show_rating = []
for link in list_of_link_for_tv_show:
  try:
    response = requests.get(link)
    soup = BeautifulSoup(response.text, "html.parser")

    rating_tag = soup.find_all("div", class_ = "jw-scoring-listing__rating")
    # print(rating_tag)
    if rating_tag:
      rating = rating_tag[1].text.split("(")[0]
      list_of_tv_show_rating.append(rating)
    else:
      list_of_tv_show_rating.append("rating not found")

  except Exception as e:
    print(e)
  time.sleep(3)

print(list_of_tv_show_rating)
print(len(list_of_tv_show_rating))
# Out:
# [' 8.8  ', ' 8.5  ', ' 8.9  ', ' 8.5  ', ' 7.6  ', ' 9.2  ', ' 6.6  ', ' 8.3  ', ' 9.0  ', ' 8.2  ', ' 8.0  ', ' 7.6  ', ' 7.2  ', ' 7.6  ', ' 6.8  ', ' 7.3  ', ' 7.5  ', ' 8.1  ', ' 8.4  ', ' 8.1  ', ' 7.2  ', ' 8.4  ', '', ' 7.1  ', ' 8.1  ', ' 7.9  ', ' 8.6  ', ' 6.1  ', ' 8.1  ', ' 8.7  ', ' 7.4  ', ' 3.4  ', ' 8.7  ', ' 8.9  ', ' 8.0  ', ' 7.8  ', ' 8.3  ', ' 8.6  ', ' 8.1  ', ' 7.2  ', ' 8.5  ', ' 8.7  ', ' 5.5  ', ' 7.5  ', ' 8.5  ', ' 8.2  ', ' 8.7  ', ' 9.5  ', ' 4.4  ', ' 7.2  ', ' 8.4  ', ' 8.7  ', ' 8.8  ', ' 8.3  ', ' 8.1  ', ' 6.5  ', ' 8.4  ', ' 8.0  ', ' 6.2  ', ' 9.3  ', ' 7.0  ', ' 8.7  ', ' 5.5  ', ' 3.8  ', ' 9.1  ', ' 8.0  ', ' 8.2  ', ' 8.7  ', ' 7.6  ', ' 8.1  ', ' 8.7  ', ' 6.7  ', ' 7.6  ', ' 6.6  ', ' 7.3  ', ' 6.5  ', ' 8.9  ', ' 8.1  ', ' 8.5  ', ' 7.9  ', ' 7.2  ', ' 7.7  ', ' 7.5  ', ' 3.7  ', ' 8.9  ', ' 8.8  ', ' 8.7  ', ' 8.3  ', ' 8.5  ', ' 8.7  ', ' 9.0  ', ' 8.1  ', ' 9.2  ', ' 3.7  ', ' 8.0  ', ' 8.3  ', ' 7.9  ', ' 9.3  ', ' 8.5  ', ' 7.1  ']
# ...

# %% [markdown]
# ## **Fetching Age Rating Details**

# %%
# Write Your Code here
list_of_tv_show_age_rating = []
for link in list_of_link_for_tv_show:
  try:
    response = requests.get(link)
    soup = BeautifulSoup(response.text,"html.parser")

    age_rating_heading = soup.find("h3", class_ = "detail-infos__subheading" , string = "Age rating")
    if age_rating_heading:
      age_rating = age_rating_heading.find_next("div", class_ = "detail-infos__value")
      list_of_tv_show_age_rating.append(age_rating.text)

    else:
      list_of_tv_show_age_rating.append("age rating not found")
  except Exception as e:
    print(e)
  time.sleep(3)

print(list_of_tv_show_age_rating)
print(len(list_of_tv_show_age_rating))
# Out:
# ['age rating not found', 'A', 'age rating not found', 'age rating not found', 'A', 'A', 'age rating not found', 'age rating not found', 'UA', 'age rating not found', 'age rating not found', 'U', 'A', 'age rating not found', 'age rating not found', 'age rating not found', 'A', 'A', 'age rating not found', 'U', 'age rating not found', 'age rating not found', 'age rating not found', 'age rating not found', 'U', 'UA', 'age rating not found', 'age rating not found', 'age rating not found', 'age rating not found', 'age rating not found', 'A', 'age rating not found', 'U', 'age rating not found', 'age rating not found', 'A', 'age rating not found', 'A', 'age rating not found', 'age rating not found', 'A', 'age rating not found', 'age rating not found', 'age rating not found', 'age rating not found', 'U', 'U', 'age rating not found', 'age rating not found', 'A', 'age rating not found', 'A', 'age rating not found', 'U', 'age rating not found', 'age rating not found', 'U', 'age rating not found
# ...

# %% [markdown]
# ## **Fetching Streaming Service details**

# %%
# Write Your Code here
list_of_tv_show_streaming_services = []
for link in list_of_link_for_tv_show:
  try:
    response = requests.get(link)
    soup = BeautifulSoup(response.text, "html.parser")

    streaming_tag = soup.find("img", class_ = "offer__icon")

    if streaming_tag:
      streaming_services = streaming_tag.get("alt")
      list_of_tv_show_streaming_services.append(streaming_services)
    else:
      list_of_tv_show_streaming_services.append("streaming services not found")

  except Exception as e:
    print(e)
  time.sleep(3)
print(list_of_tv_show_streaming_services)
# Out:
# ['Hotstar', 'Amazon Prime Video', 'Amazon Prime Video', 'Amazon Prime Video', 'Netflix', 'Jio Cinema', 'Netflix', 'Jio Cinema', 'Amazon Prime Video', 'Netflix', 'Netflix', 'Amazon Prime Video', 'Amazon Prime Video', 'Netflix', 'Amazon Prime Video', 'Netflix', 'VI movies and tv', 'Netflix', 'Crunchyroll', 'Amazon Prime Video', 'Netflix', 'Amazon Prime Video', 'Netflix', 'streaming services not found', 'Netflix', 'Sony Liv', 'Crunchyroll', 'Netflix', 'Netflix', 'Amazon Prime Video', 'MX Player', 'Alt Balaji', 'Amazon Prime Video', 'Jio Cinema', 'streaming services not found', 'Apple TV Plus', 'Jio Cinema', 'Alt Balaji', 'Amazon Prime Video', 'Hotstar', 'Jio Cinema', 'Jio Cinema', 'VI movies and tv', 'streaming services not found', 'Hotstar', 'Netflix', 'Crunchyroll', 'Netflix', 'Netflix', 'Amazon miniTV', 'Jio Cinema', 'Netflix', 'Netflix', 'Jio Cinema', 'Netflix', 'Netflix', 'Amazon Prime Video', 'Netflix', 'Amazon Prime Video', 'Sony Liv', 'Hotstar', 'Netflix', 'Netflix', 'Jio Cinema
# ...

# %% [markdown]
# ## **Fetching Duration Details**

# %%
# Write Your Code here
list_of_tv_show_runtime = []
for link in list_of_link_for_tv_show:
  try:
    response = requests.get(link)
    soup = BeautifulSoup(response.text, "html.parser")

    runtime_heading= soup.find("h3", class_ = "detail-infos__subheading", string= "Runtime")

    if runtime_heading:
      runtime = runtime_heading.find_next("div", class_ = "detail-infos__value")
      list_of_tv_show_runtime.append(runtime.text)
    else:
      list_of_tv_show_runtime.append("runtime Not Found")

  except Exception as e:
    print(e)
  time.sleep(3)

print(list_of_tv_show_runtime)
print(len(list_of_tv_show_runtime))
# Out:
# ['59min', '59min', '33min', '50min', '56min', '58min', '55min', '24min', '25min', '56min', '34min', '19min', '45min', '54min', '48min', '52min', '37min', '50min', '24min', '46min', '50min', '56min', '1h 29min', '28min', '47min', '44min', '23min', '50min', '32min', '48min', '43min', '44min', '45min', '1h 1min', '42min', '36min', '58min', '26min', '48min', '54min', '47min', '58min', '20min', '42min', '21min', '51min', '24min', '47min', '59min', '24min', '1h 2min', '1h 1min', '58min', '40min', '43min', '34min', '23min', '43min', '40min', '52min', '45min', '50min', '51min', '43min', '29min', '44min', '49min', '24min', '57min', '50min', '44min', '21min', '48min', '48min', '52min', '43min', '24min', '29min', '59min', '44min', '54min', '42min', '41min', '25min', '52min', '47min', '1h 0min', '24min', '54min', '26min', '33min', '43min', '44min', '1h 15min', '59min', '31min', '46min', '1h 5min', '1h 1min', '37min']
# 100

# %% [markdown]
# ## **Creating TV Show DataFrame**

# %%
# Write Your Code here
tv_show_dic_df = {
    "Movie-Title" : list_of_tv_show_title,
    "Release-Year" : list_of_tv_show_release_year,
    "Genre": list_of_tv_show_genre,
    "IMDB-Rating" : list_of_tv_show_rating,
    "Runtime": list_of_tv_show_runtime,
    "Age-Rating": list_of_tv_show_age_rating,
    "Streaming-Services": list_of_tv_show_streaming_services,
    "Links": list_of_links,
}
tv_show_df = pd.DataFrame(tv_show_dic_df)
tv_show_df
# Out:
#           Movie-Title Release-Year  \
# 0             Shōgun       (2024)
# 1            Fallout       (2024)
# 2          Panchayat       (2020)
# 3           Mirzapur       (2018)
# 4     3 Body Problem       (2024)
# ..                ...          ...
# 95   College Romance       (2018)
# 96             Aarya       (2020)
# 97         Chernobyl       (2019)
# 98         Westworld       (2016)
# 99         Dr. Arora       (2022)
#
#                                                 Genre IMDB-Rating  Runtime  \
# 0                      Drama, War & Military, History       8.8      59min
# 1   Action & Adventure, Drama, Science-Fiction, Wa...       8.5      59min
# 2                                       Drama, Comedy       8.9      33min
# 3   Crime, Action & Adventure, Drama, Mystery & Th...       8.5      50min
# 4   Mystery & Thriller, Drama, Science-Fiction, Fa...       7.6      56min
# ..                                                ...         ...      ...
# ...

# %% [markdown]
# ## **Task 2 :- Data Filtering & Analysis**

# %%
df = movie_df.copy()
df
# Out:
#                            Movie-Title Release-Year  \
# 0                     Laapataa Ladies       (2024)
# 1    Teri Baaton Mein Aisa Uljha Jiya       (2024)
# 2                             Premalu       (2024)
# 3                         Article 370       (2024)
# 4                      Dune: Part Two       (2024)
# ..                                 ...          ...
# 95                               DeAr       (2024)
# 96               New York, I Love You       (2008)
# 97                         The Intern       (2015)
# 98    Rocky Aur Rani Kii Prem Kahaani       (2023)
# 99                Operation Valentine       (2024)
#
#                                                 Genre       IMDB-Rating  \
# 0                                       Comedy, Drama             8.5
# 1             Comedy, Drama, Romance, Science-Fiction             6.4
# 2                                     Romance, Comedy             7.9
# ...

# %%
# Write Your Code here
from datetime import datetime
df["Release-Year"] = df["Release-Year"].astype(int)
current_year = datetime.now().year
recent_movies = df[df["Release-Year"] > current_year - 2]
recent_movies
# Out:
#                            Movie-Title  Release-Year  \
# 0                     Laapataa Ladies           2024
# 1    Teri Baaton Mein Aisa Uljha Jiya           2024
# 2                             Premalu           2024
# 3                         Article 370           2024
# 4                      Dune: Part Two           2024
# ..                                 ...           ...
# 92                              Wonka           2023
# 94                      The Holdovers           2023
# 95                               DeAr           2024
# 98    Rocky Aur Rani Kii Prem Kahaani           2023
# 99                Operation Valentine           2024
#
#                                                 Genre       IMDB-Rating  \
# 0                                       Comedy, Drama             8.5
# 1             Comedy, Drama, Romance, Science-Fiction             6.4
# 2                                     Romance, Comedy             7.9
# ...

# %% [markdown]
# ## **Calculating Mean IMDB Ratings for both Movies and Tv Shows**

# %%
# Write Your Code here
recent_movies["IMDB-Rating"] = recent_movies["IMDB-Rating"].replace("rating not found", 0)
recent_movies["IMDB-Rating"] = recent_movies["IMDB-Rating"].astype(float)
filter_movies = recent_movies[recent_movies["IMDB-Rating"] >= 7]
filter_movies
# Out:
# <ipython-input-31-dfe91b59349d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recent_movies["IMDB-Rating"] = recent_movies["IMDB-Rating"].replace("rating not found", 0)
# <ipython-input-31-dfe91b59349d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recent_movies["IMDB-Rating"] = recent_movies["IMDB-Rating"].astype(float)
#                     Movie-Title  Release-Year  \
# 0              Laapataa Ladies           2024
# 2                      Premalu           2024
# ...

# %% [markdown]
# ## **Analyzing Top Genres**

# %%
# Write Your Code here
from wordcloud import WordCloud
text = " ".join(df["Genre"])

wordcloud = WordCloud(width = 1000 , height = 600 ,background_color= "white").generate(text)
wordcloud.to_file("myimage.jpg")

# %%
#Let's Visvalize it using word cloud
import matplotlib.pyplot as plt
plt.figure(figsize = (8,5))
plt.imshow(wordcloud)
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## **Finding Predominant Streaming Service**

# %%
# Write Your Code here
streaming_service_count = df.groupby("Streaming-Services").size().reset_index(name = "Count")
streaming_service_count_sorted = streaming_service_count.sort_values(by= "Count", ascending = False)
streaming_service_count_sorted
# Out:
#               Streaming-Services  Count
# 0             Amazon Prime Video     30
# 2                       Apple TV     18
# 8                        Netflix     17
# 13  streaming services not found     11
# 4                     Bookmyshow      9
# 11                          Zee5      4
# 9                       Sony Liv      3
# 1                   Amazon Video      2
# 3                  Apple TV Plus      1
# 5                        Hotstar      1
# 6                     Jio Cinema      1
# 7                 Lionsgate Play      1
# 10                       Tubi TV      1
# 12                           aha      1

# %%
#Let's Visvalize it using word cloud
text = " ".join(df["Streaming-Services"])
wordcloud = WordCloud(width = 1000, height = 600, background_color = "white").generate(text)
plt.figure(figsize=(8,5))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ## **Task 3 :- Data Export**

# %%
#saving final dataframe as Final Data in csv format
df.to_csv("Original_DF.csv", index= False)
print("Export Done")
# Out:
# Export Done

# %%
#saving filter data as Filter Data in csv format
filter_movies.to_csv("filter_movies.csv", index = False)
print("Export Done")
# Out:
# Export Done

# %% [markdown]
# # **Dataset Drive Link (View Access with Anyone) -**

# %% [markdown]
# # ***Congratulations!!! You have completed your Assignment.***
